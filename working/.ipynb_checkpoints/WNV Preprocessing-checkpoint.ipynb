# %% [markdown]
# # Preprocessing and Feature Engineering
#
# In this notebook I will create a clean dataset ready to model through feature engineering and standardization.
#
# First load the data from EDA, and clean up any extraneous columns that will not be used in prediction.  Then I will split the data into predictors and target.
#
# Next I will perform PCA to see the principal components of the data.  The principal components may be used as input to the modelling phase.
#
# Finally I will perform a train-test split and apply a basic logistic regression model to the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import traceback

# %%
random_seed = 27

# %%
train = pd.read_csv('train_w_aggregated_weather.csv',index_col=0)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4616 entries, 0 to 4615
# Data columns (total 98 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    4616 non-null   object
#  1   Trap                    4616 non-null   object
#  2   Address                 4616 non-null   object
#  3   Block                   4616 non-null   int64
#  4   Street                  4616 non-null   object
#  5   AddressNumberAndStreet  4616 non-null   object
#  6   Latitude                4616 non-null   float64
#  7   Longitude               4616 non-null   float64
#  8   AddressAccuracy         4616 non-null   int64
#  9   RESTUANS                4616 non-null   int64
#  10  PIPIENS                 4616 non-null   int64
#  11  SALINARIUS              4616 non-null   int64
#  12  TERRITANS               4616 non-null   int64
#  13  TARSALIS                4616 non-null   int64
#  14  ERRATICUS               4616 non-null   int64
#  15  NumMosquitos            4616 non-null   int64
#  16  WnvPresent              4616 non-null   float64
#  17  Year                    4616 non-null   int64
#  18  Month                   4616 non-null   int64
#  19  Week                    4616 non-null   int64
#  20  WnvPerc_yearly          4616 non-null   float64
#  21  WnvPerc_monthly         4616 non-null   float64
#  22  WnvPerc_weekly          4616 non-null   float64
#  23  Station                 4616 non-null   int64
#  24  Station_dist            4616 non-null   float64
#  25  Tmax                    4616 non-null   int64
#  26  Tmin                    4616 non-null   int64
#  27  Tavg                    4616 non-null   int64
#  28  Depart                  4616 non-null   float64
#  29  DewPoint                4616 non-null   int64
#  30  WetBulb                 4616 non-null   int64
#  31  Heat                    4616 non-null   int64
#  32  Cool                    4616 non-null   int64
#  33  CodeSum                 4616 non-null   object
#  34  PrecipTotal             4616 non-null   float64
#  35  StnPressure             4616 non-null   float64
#  36  SeaLevel                4616 non-null   float64
#  37  AvgSpeed                4616 non-null   float64
#  38  WindDirection           4616 non-null   int64
#  39  WindSpeed               4616 non-null   float64
#  40  StationLat              4616 non-null   float64
#  41  StationLong             4616 non-null   float64
#  42  StationElev_ft          4616 non-null   int64
#  43  Tavg_lag1               4616 non-null   float64
#  44  Tavg_lag2               4616 non-null   float64
#  45  Tavg_lag3               4616 non-null   float64
#  46  Tavg_lag4               4616 non-null   float64
#  47  Tavg_lag5               4616 non-null   float64
#  48  DewPoint_lag1           4616 non-null   float64
#  49  DewPoint_lag2           4616 non-null   float64
#  50  DewPoint_lag3           4616 non-null   float64
#  51  DewPoint_lag4           4616 non-null   float64
#  52  DewPoint_lag5           4616 non-null   float64
#  53  WetBulb_lag1            4616 non-null   float64
#  54  WetBulb_lag2            4616 non-null   float64
#  55  WetBulb_lag3            4616 non-null   float64
#  56  WetBulb_lag4            4616 non-null   float64
#  57  WetBulb_lag5            4616 non-null   float64
#  58  WindSpeed_lag1          4616 non-null   float64
#  59  WindSpeed_lag2          4616 non-null   float64
#  60  WindSpeed_lag3          4616 non-null   float64
#  61  WindSpeed_lag4          4616 non-null   float64
#  62  WindSpeed_lag5          4616 non-null   float64
#  63  AvgSpeed_lag1           4616 non-null   float64
#  64  AvgSpeed_lag2           4616 non-null   float64
#  65  AvgSpeed_lag3           4616 non-null   float64
#  66  AvgSpeed_lag4           4616 non-null   float64
#  67  AvgSpeed_lag5           4616 non-null   float64
#  68  StnPressure_lag1        4616 non-null   float64
#  69  StnPressure_lag2        4616 non-null   float64
#  70  StnPressure_lag3        4616 non-null   float64
#  71  StnPressure_lag4        4616 non-null   float64
#  72  StnPressure_lag5        4616 non-null   float64
#  73  PrecipTotal_lag1        4616 non-null   float64
#  74  PrecipTotal_lag2        4616 non-null   float64
#  75  PrecipTotal_lag3        4616 non-null   float64
#  76  PrecipTotal_lag4        4616 non-null   float64
#  77  PrecipTotal_lag5        4616 non-null   float64
#  78  PrecipTotal_lag6        4616 non-null   float64
#  79  PrecipTotal_lag7        4616 non-null   float64
#  80  PrecipTotal_lag8        4616 non-null   float64
#  81  PrecipTotal_lag9        4616 non-null   float64
#  82  PrecipTotal_lag10       4616 non-null   float64
#  83  Tavg_agg3               4616 non-null   float64
#  84  PrecipTotal_agg3        4616 non-null   float64
#  85  DewPoint_agg3           4616 non-null   float64
#  86  WetBulb_agg3            4616 non-null   float64
#  87  StnPressure_agg3        4616 non-null   float64
#  88  SeaLevel_agg3           4616 non-null   float64
#  89  AvgSpeed_agg3           4616 non-null   float64
#  90  Tavg_agg7               4616 non-null   float64
#  91  PrecipTotal_agg7        4616 non-null   float64
#  92  DewPoint_agg7           4616 non-null   float64
#  93  WetBulb_agg7            4616 non-null   float64
#  94  StnPressure_agg7        4616 non-null   float64
#  95  SeaLevel_agg7           4616 non-null   float64
#  96  AvgSpeed_agg7           4616 non-null   float64
#  97  Daylight                4616 non-null   float64
# dtypes: float64(70), int64(22), object(6)
# memory usage: 3.5+ MB

# %%
print('Length of data:',train.shape[0])
print('Duplicate Traps & dates:',train.duplicated(subset=['Date','Trap']).sum())
# Out:
# Length of data: 4616
# Duplicate Traps & dates: 0

# %% [markdown]
# Looks good. I will clean up (drop) some columns that can't be used for prediction.

# %%
### drop mosquito species columns, won't have that for predicting 
train = train.drop(['RESTUANS','PIPIENS','SALINARIUS','TERRITANS',\
                    'TARSALIS','ERRATICUS'],axis=1)

# %%
### Drop extraneous columns that won't be used in modeling
train = train.drop(['Date','Trap','Address','Block','Street',\
                    'AddressNumberAndStreet','Latitude','Longitude',\
                   'AddressAccuracy','Station'],axis=1)

# %%
### Drop CodeSum string columns
#train = train.drop(['CodeSum_3days','CodeSum_7days','CodeSum_14days']\
                   #,axis=1)
train = train.drop('CodeSum',axis=1)

# %%
### Finally drop the number of mosquitos column and Yearly columns
### as this will not be available for prediction
train = train.drop('NumMosquitos',axis=1)
train = train.drop(['Year','WnvPerc_yearly'],axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4616 entries, 0 to 4615
# Data columns (total 78 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WnvPresent         4616 non-null   float64
#  1   Month              4616 non-null   int64
#  2   Week               4616 non-null   int64
#  3   WnvPerc_monthly    4616 non-null   float64
#  4   WnvPerc_weekly     4616 non-null   float64
#  5   Station_dist       4616 non-null   float64
#  6   Tmax               4616 non-null   int64
#  7   Tmin               4616 non-null   int64
#  8   Tavg               4616 non-null   int64
#  9   Depart             4616 non-null   float64
#  10  DewPoint           4616 non-null   int64
#  11  WetBulb            4616 non-null   int64
#  12  Heat               4616 non-null   int64
#  13  Cool               4616 non-null   int64
#  14  PrecipTotal        4616 non-null   float64
#  15  StnPressure        4616 non-null   float64
#  16  SeaLevel           4616 non-null   float64
#  17  AvgSpeed           4616 non-null   float64
#  18  WindDirection      4616 non-null   int64
#  19  WindSpeed          4616 non-null   float64
#  20  StationLat         4616 non-null   float64
#  21  StationLong        4616 non-null   float64
#  22  StationElev_ft     4616 non-null   int64
#  23  Tavg_lag1          4616 non-null   float64
#  24  Tavg_lag2          4616 non-null   float64
#  25  Tavg_lag3          4616 non-null   float64
#  26  Tavg_lag4          4616 non-null   float64
#  27  Tavg_lag5          4616 non-null   float64
#  28  DewPoint_lag1      4616 non-null   float64
#  29  DewPoint_lag2      4616 non-null   float64
#  30  DewPoint_lag3      4616 non-null   float64
#  31  DewPoint_lag4      4616 non-null   float64
#  32  DewPoint_lag5      4616 non-null   float64
#  33  WetBulb_lag1       4616 non-null   float64
#  34  WetBulb_lag2       4616 non-null   float64
#  35  WetBulb_lag3       4616 non-null   float64
#  36  WetBulb_lag4       4616 non-null   float64
#  37  WetBulb_lag5       4616 non-null   float64
#  38  WindSpeed_lag1     4616 non-null   float64
#  39  WindSpeed_lag2     4616 non-null   float64
#  40  WindSpeed_lag3     4616 non-null   float64
#  41  WindSpeed_lag4     4616 non-null   float64
#  42  WindSpeed_lag5     4616 non-null   float64
#  43  AvgSpeed_lag1      4616 non-null   float64
#  44  AvgSpeed_lag2      4616 non-null   float64
#  45  AvgSpeed_lag3      4616 non-null   float64
#  46  AvgSpeed_lag4      4616 non-null   float64
#  47  AvgSpeed_lag5      4616 non-null   float64
#  48  StnPressure_lag1   4616 non-null   float64
#  49  StnPressure_lag2   4616 non-null   float64
#  50  StnPressure_lag3   4616 non-null   float64
#  51  StnPressure_lag4   4616 non-null   float64
#  52  StnPressure_lag5   4616 non-null   float64
#  53  PrecipTotal_lag1   4616 non-null   float64
#  54  PrecipTotal_lag2   4616 non-null   float64
#  55  PrecipTotal_lag3   4616 non-null   float64
#  56  PrecipTotal_lag4   4616 non-null   float64
#  57  PrecipTotal_lag5   4616 non-null   float64
#  58  PrecipTotal_lag6   4616 non-null   float64
#  59  PrecipTotal_lag7   4616 non-null   float64
#  60  PrecipTotal_lag8   4616 non-null   float64
#  61  PrecipTotal_lag9   4616 non-null   float64
#  62  PrecipTotal_lag10  4616 non-null   float64
#  63  Tavg_agg3          4616 non-null   float64
#  64  PrecipTotal_agg3   4616 non-null   float64
#  65  DewPoint_agg3      4616 non-null   float64
#  66  WetBulb_agg3       4616 non-null   float64
#  67  StnPressure_agg3   4616 non-null   float64
#  68  SeaLevel_agg3      4616 non-null   float64
#  69  AvgSpeed_agg3      4616 non-null   float64
#  70  Tavg_agg7          4616 non-null   float64
#  71  PrecipTotal_agg7   4616 non-null   float64
#  72  DewPoint_agg7      4616 non-null   float64
#  73  WetBulb_agg7       4616 non-null   float64
#  74  StnPressure_agg7   4616 non-null   float64
#  75  SeaLevel_agg7      4616 non-null   float64
#  76  AvgSpeed_agg7      4616 non-null   float64
#  77  Daylight           4616 non-null   float64
# dtypes: float64(67), int64(11)
# memory usage: 2.8 MB

# %% [markdown]
# Looks great the data set is all numeric and there are no nulls to be found.  Now I will split the train and test data.

# %%
### Split into X and y
y = train['WnvPresent']
X = train.drop('WnvPresent',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify=y,\
                                 test_size=.2,random_state=random_seed)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
print(type(X_train))
# Out:
# (3692, 77)
# (924, 77)
# (3692,)
# (924,)
# <class 'pandas.core.frame.DataFrame'>

# %%
print('Testing Fraction positive:  {:.3f} '.format(y_test.sum()/y_test.shape[0]))
print('Training Fraction positive: {:.3f}'.format(y_train.sum()/y_train.shape[0]))
# Out:
# Testing Fraction positive:  0.083
# Training Fraction positive: 0.083

# %% [markdown]
# That data are now split into testing and training set, and each now has the same proportion of positive cases.

# %% [markdown]
# Now I will implement Rahul's function for calculating the predictive power of each feature.  Next I will filter out features that are have no predictive power or very high predicitive power.  Finally I will check to colinearity of the features in the training data set and drop any features that are highly correlative to others. (Helping to reduce model overfitting to the training set).

# %%
### Function from Rahul to calculate the Information Value (IV) of each feature
### I will go through each line and add my own personal comments so 
### that I can understand what this function is doing. 


max_bin = 20
force_bin = 3
import pandas.core.algorithms as algos
import scipy.stats.stats as stats


# define a binning function
### this function is for binning and calculating the Weight of Evidence 
### for the target and the Information Value for the feature
### and the In
def mono_bin(Y, X, n = max_bin):    
    ### create new dataframe of series feature and series y
    df1 = pd.DataFrame({"X": X, "Y": Y})
    
    ### check to see if any nulls in feature and seperate nulls out
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    #print("justmiss", justmiss)
    #print("notmiss", notmiss)
    
    
    ### while loop until Spearman correlation coefficient is between [-1,1]
    ### Finding minumum bin size that results in 'abs(r)' of >1???
    
    r = 0
    while np.abs(r) < 1:
        ### Try creation of new dataframe with max or less bin size 'n'
        ### create dataframe with feature, target and binned feature 
        ### create 'd2' group by object on 'Bucket'
        ### calculate Spearman correlation 'r' and p-value from mean of feature and target
        ### If exception reduce bin size by one and try again
        
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y,\
                               "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
                             
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            #print("I am here 1",r, n,len(d2))
            n = n - 1 
            
            
        except Exception as e:
            n = n - 1
            #print("I am here e",n)

    ### If length of d2 is 1 (ie 1 bucket for all of feature) do this
    if len(d2) == 1:
        #print("I am second step ",r, n)
        
        ### force 'n' to 3 and calculate quantiles of feature from (0,0.5,1) 
        ### to be used as bins, if not 3 unique because of heavily skewed data
        ### manually create bin
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
            
        ### Create new dataframe bucketed by manual bins
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    ### Create new dataframe from aggregating the binned dataframe
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        #print(justmiss.count().Y)
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    ### add more features to d3 describing the 'events' of the target
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    print(np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT))
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    #print("hi",d3.IV )
    d3 = d3.reset_index(drop=True)
    
    return(d3)

def data_vars(df1, target):
    import traceback
    
    
    ### Extract raw traceback from error in one of the two sub functions
    ### assign traceback elemnts to variables
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    
    ###
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    
    ### get column names from df1
    x = df1.dtypes.index
    
    count = -1
    ### Loop through columns
    for i in x:
        print(i)
        if i.upper() not in (final.upper()):
            ### test if numeric and not a one-hot encoding
            if np.issubdtype(df1[i], np.number) and len(pd.Series.unique(df1[i])) > 2:
                #print("Number and unique value greater than 2")
                ###  pass target and feature to 'mono_bin'
                conv = mono_bin(target, df1[i])
                
                ### assign feature name to 'conv'
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                #print("I am here 2")
                ###  pass target and feature to 'char_bin'
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1

            ### First time run through the loop where count==0,
            ### create new df from current
            if count == 0:
                iv_df = conv
            ### on subsequent loops append rows to bottom of 'iv_df'
            ### of next feature and scoring calcs
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    ### aggregate 'iv_df' taking the maximum ?correlation? score 
    ### for each feature and creating a new summary df with columns 
    ### 'VAR_NAME' & 'IV'
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    ### return detailed df with all computed features
    ### and summary of only max values and feature names
    return(iv_df,iv)

# %%
iv_df, iv = data_vars(X_train,y_train)
# Out:
# Month
# 0    0.023442
# 1   -0.063943
# dtype: float64
# Week
# 0   -0.695860
# 1    0.525263
# dtype: float64
# WnvPerc_monthly
# 0   -1.623266
# 1    0.041682
# 2    0.902687
# dtype: float64
# WnvPerc_weekly
# 0        -inf
# 1   -1.541127
# 2   -0.625741
# 3    0.090856
# 4    0.771610
# 5    1.150368
# dtype: float64
# Station_dist
# 0    0.176430
# 1   -0.207433
# dtype: float64
# Tmax
# C:\Users\blain\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0   -0.039554
# 1    0.047672
# dtype: float64
# Tmin
# 0   -0.434256
# 1    0.330288
# dtype: float64
# Tavg
# 0   -0.140065
# 1    0.141578
# dtype: float64
# Depart
# 0   -0.193553
# 1    0.190381
# dtype: float64
# DewPoint
# 0   -0.489503
# 1   -0.240641
# 2    0.536245
# dtype: float64
# WetBulb
# 0    -1.072142
# 1         -inf
# 2    -0.429555
# 3     0.040062
# 4          NaN
# 5     0.332265
# 6    -0.590650
# 7    -1.398775
# 8     0.643794
# 9     0.545056
# 10    0.069436
# 11    0.295766
# 12    0.537815
# dtype: float64
# Heat
# 0    0.117716
# 1   -1.318889
# dtype: float64
# Cool
# C:\Users\blain\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0   -0.140065
# 1    0.141578
# dtype: float64
# PrecipTotal
# 0    0.004536
# 1   -0.242343
# dtype: float64
# StnPressure
# 0    0.061537
# 1   -0.064936
# dtype: float64
# SeaLevel
# 0   -0.042502
# 1    0.043804
# dtype: float64
# AvgSpeed
# 0    0.264311
# 1    0.017346
# 2   -0.365548
# dtype: float64
# WindDirection
# 0   -0.132253
# 1    0.140173
# dtype: float64
# WindSpeed
# 0    0.300522
# 1    0.249166
# 2   -0.341078
# 3   -0.444701
# dtype: float64
# StationLat
# StationLong
# StationElev_ft
# Tavg_lag1
# 0   -0.654588
# 1   -0.273826
# 2    0.282363
# 3    0.433104
# dtype: float64
# Tavg_lag2
# 0   -0.525315
# 1   -0.109886
# 2   -0.097210
# 3    0.052366
# 4    0.237917
# 5    0.390450
# dtype: float64
# Tavg_lag3
# 0   -0.078442
# 1    0.076386
# dtype: float64
# Tavg_lag4
# 0   -0.039725
# 1    0.041921
# dtype: float64
# Tavg_lag5
# 0   -0.305257
# 1    0.262642
# dtype: float64
# DewPoint_lag1
# 0   -0.645642
# 1   -0.517933
# 2    0.231045
# 3    0.636251
# dtype: float64
# DewPoint_lag2
# 0   -0.227280
# 1   -0.186661
# 2    0.371181
# dtype: float64
# DewPoint_lag3
# 0   -0.106079
# 1    0.123701
# dtype: float64
# DewPoint_lag4
# 0   -0.030299
# 1    0.033822
# dtype: float64
# DewPoint_lag5
# 0   -0.551009
# 1    0.066220
# 2    0.344822
# dtype: float64
# WetBulb_lag1
# 0   -0.656343
# 1   -0.645538
# 2    0.399068
# 3    0.614711
# dtype: float64
# WetBulb_lag2
# 0   -0.404677
# 1   -0.070055
# 2    0.438696
# dtype: float64
# WetBulb_lag3
# 0   -0.170714
# 1   -0.066531
# 2    0.252379
# dtype: float64
# WetBulb_lag4
# 0   -0.254445
# 1    0.048200
# 2    0.190273
# dtype: float64
# WetBulb_lag5
# 0   -0.790650
# 1    0.206047
# 2    0.320326
# dtype: float64
# WindSpeed_lag1
# 0    0.137268
# 1    0.076780
# 2   -0.035282
# 3   -0.213119
# dtype: float64
# WindSpeed_lag2
# 0   -0.179484
# 1    0.168953
# dtype: float64
# WindSpeed_lag3
# 0    0.199489
# 1    0.139799
# 2   -0.448716
# dtype: float64
# WindSpeed_lag4
# 0   -0.070921
# 1    0.068533
# dtype: float64
# WindSpeed_lag5
# 0    0.158518
# 1   -0.182920
# dtype: float64
# AvgSpeed_lag1
# 0   -0.059056
# 1    0.057917
# dtype: float64
# AvgSpeed_lag2
# 0    0.033643
# 1   -0.039946
# dtype: float64
# AvgSpeed_lag3
# 0    0.181438
# 1    0.077898
# 2   -0.318329
# dtype: float64
# AvgSpeed_lag4
# 0    0.309277
# 1    0.076218
# 2   -0.239834
# 3   -0.287321
# dtype: float64
# AvgSpeed_lag5
# 0    0.266352
# 1   -0.364124
# dtype: float64
# StnPressure_lag1
# 0    0.067696
# 1   -0.075614
# dtype: float64
# StnPressure_lag2
# 0   -0.115592
# 1    0.113834
# dtype: float64
# StnPressure_lag3
# 0   -0.193921
# 1    0.185378
# dtype: float64
# StnPressure_lag4
# 0   -0.436499
# 1   -0.065122
# 2    0.374842
# dtype: float64
# StnPressure_lag5
# 0   -0.207873
# 1    0.051127
# 2    0.064570
# 3    0.123116
# dtype: float64
# PrecipTotal_lag1
# 0   -0.019689
# 1    0.450804
# dtype: float64
# PrecipTotal_lag2
# 0   -0.046401
# 1    0.771403
# dtype: float64
# PrecipTotal_lag3
# 0   -0.121580
# 1    0.229823
# dtype: float64
# PrecipTotal_lag4
# C:\Users\blain\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0    0.015186
# 1        -inf
# dtype: float64
# PrecipTotal_lag5
# 0   -0.051223
# 1    1.266849
# dtype: float64
# PrecipTotal_lag6
# 0   -0.183224
# 1    0.256242
# dtype: float64
# PrecipTotal_lag7
# 0    0.011718
# 1   -0.781340
# dtype: float64
# PrecipTotal_lag8
# 0   -0.006337
# 1    0.237230
# dtype: float64
# PrecipTotal_lag9
# 0   -0.008952
# 1    0.787276
# dtype: float64
# PrecipTotal_lag10
# 0    0.020642
# 1   -0.518049
# dtype: float64
# Tavg_agg3
# 0   -0.875981
# 1   -0.078759
# 2    0.279023
# 3    0.337421
# dtype: float64
# PrecipTotal_agg3
# 0    0.065453
# 1   -0.070556
# dtype: float64
# DewPoint_agg3
# 0   -0.808739
# 1   -0.662932
# 2   -0.460714
# 3    0.006641
# 4    0.301489
# 5    0.349021
# 6    0.706424
# dtype: float64
# WetBulb_agg3
# 0   -1.028914
# 1   -0.371234
# 2    0.366908
# 3    0.527663
# dtype: float64
# StnPressure_agg3
# 0    0.006907
# 1   -0.007224
# dtype: float64
# SeaLevel_agg3
# 0   -0.008106
# 1    0.008498
# dtype: float64
# AvgSpeed_agg3
# 0    0.205731
# 1    0.051141
# 2   -0.319200
# dtype: float64
# Tavg_agg7
# 0   -0.724464
# 1    0.165410
# 2    0.323974
# dtype: float64
# PrecipTotal_agg7
# 0   -0.147663
# 1   -0.123115
# 2   -0.009412
# 3    0.242507
# dtype: float64
# DewPoint_agg7
# 0   -0.967292
# 1   -0.812888
# 2   -0.269742
# 3    0.138865
# 4    0.333533
# 5    0.747667
# dtype: float64
# WetBulb_agg7
# 0   -0.794763
# 1   -0.682900
# 2    0.393449
# 3    0.522118
# dtype: float64
# StnPressure_agg7
# 0   -0.338113
# 1    0.265434
# dtype: float64
# SeaLevel_agg7
# 0   -0.372491
# 1    0.293447
# dtype: float64
# AvgSpeed_agg7
# 0    0.324241
# 1    0.276863
# 2   -0.277435
# 3   -0.573131
# dtype: float64
# Daylight
# 0    0.531929
# 1   -1.063895
# dtype: float64

# %%
iv.sort_values('IV',ascending=False).head(20)
# Out:
#            VAR_NAME        IV
# 75  WnvPerc_monthly  0.992365
# 76   WnvPerc_weekly  0.727134
# 9          Daylight  0.540767
# 59             Week  0.354774
# 13    DewPoint_agg7  0.352714
# 61     WetBulb_agg3  0.334745
# 62     WetBulb_agg7  0.328900
# 63     WetBulb_lag1  0.321267
# 60          WetBulb  0.315937
# 12    DewPoint_agg3  0.273130
# 14    DewPoint_lag1  0.273120
# 67     WetBulb_lag5  0.203553
# 11         DewPoint  0.198555
# 50        Tavg_agg3  0.190520
# 51        Tavg_agg7  0.178461
# 52        Tavg_lag1  0.174102
# 19             Heat  0.153321
# 58             Tmin  0.141740
# 2     AvgSpeed_agg7  0.134073
# 18    DewPoint_lag5  0.130675

# %% [markdown]
# Looks good. Now to filter out features with very low (0.01) and very high (0.8) information value.

# %%
features = list(iv[(iv['IV'] >= 0.01) & (iv['IV'] <= 0.8)]['VAR_NAME'])
X2 = X_train[features]

display(X2.shape)

X2.head()
# Out:
# (3692, 56)
#       AvgSpeed  AvgSpeed_agg3  AvgSpeed_agg7  AvgSpeed_lag3  AvgSpeed_lag4  \
# 1916      10.4      11.500000       8.914286            7.7            7.4
# 2613      10.6       8.366667       7.971429            9.2            7.0
# 2022       7.3       6.633333       8.242857            8.0           10.1
# 4363       6.0       7.566667       6.971429            4.6            8.7
# 1530       9.2       8.500000       7.928571            6.6            6.8
#
#       AvgSpeed_lag5  Cool   Daylight  Depart  DewPoint  ...  WetBulb_lag3  \
# 1916            5.2     0  14.900000   -10.0        52  ...          60.0
# 2613            5.8    13  15.200000     6.0        61  ...          67.0
# 2022            8.6     5  14.483333    -4.0        54  ...          66.0
# 4363            5.8     9  12.950000     7.0        55  ...          60.0
# 1530            8.3     0  15.016667    -8.0        47  ...          55.0
#
#       WetBulb_lag4  WetBulb_lag5  WindDirection  WindSpeed  WindSpeed_lag1  \
# 1916          59.0          60.0            290       10.1             9.6
# 2613          61.0          60.0            160        9.2             3.9
# 2022          66.0          64.0            260        6.2             4.4
# 4363          64.0          69.0            170        4.3             9.2
# 1530          55.0          54.0             30        8.3             1.0
#
#       WindSpeed_lag2  WindSpeed_lag3  WindSpeed_lag5  WnvPerc_weekly
# 1916            10.0             7.5             1.9        0.055794
# 2613             7.2             6.4             3.9        0.004000
# 2022             4.2             6.4             8.0        0.095930
# 4363             6.4             1.5             3.9        0.194872
# 1530             2.9             1.8             6.8        0.000000
#
# [5 rows x 56 columns]

# %% [markdown]
# Excellent. I have reduced the number of features from 121  to 94.  Now I am sure some of the features are highly correlated.  I will asses the colinearity of the data and then remove any highly correlative features.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def iterate_vif(df, vif_threshold=5, max_vif=6):
    count = 0
    while max_vif > vif_threshold:
        count += 1
        print("Iteration # "+str(count))
        
        ### Create data frame with features column and 
        ### variance inflation factor column
        vif = pd.DataFrame()
        vif["VIFactor"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
        vif["features"] = df.columns
        
        
        
        if vif['VIFactor'].max() > vif_threshold:
            print('Removing %s with VIF of %f' % (vif[vif['VIFactor'] == vif['VIFactor'].max()]['features'].values[0], vif['VIFactor'].max()))
            df = df.drop(vif[vif['VIFactor'] == vif['VIFactor'].max()]['features'].values[0], axis=1)
            max_vif = vif['VIFactor'].max()
        else:
            print('Complete')
            return df, vif.sort_values('VIFactor')

# %%
X1 = X2._get_numeric_data()
final_df, final_vif = iterate_vif(X1)
# Out:
# Iteration # 1
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing Cool with VIF of inf
# Iteration # 2
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing DewPoint with VIF of inf
# Iteration # 3
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing StationElev_ft with VIF of inf
# Iteration # 4
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing Tavg with VIF of inf
# Iteration # 5
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing WetBulb with VIF of inf
# Iteration # 6
# Removing StationLong with VIF of 56596471.658723
# Iteration # 7
# Removing StnPressure_agg7 with VIF of 4007777.822849
# Iteration # 8
# Removing SeaLevel_agg7 with VIF of 2964101.572330
# Iteration # 9
# Removing StnPressure_lag4 with VIF of 749820.990046
# Iteration # 10
# Removing WetBulb_agg7 with VIF of 491693.838491
# Iteration # 11
# Removing StnPressure_lag3 with VIF of 373326.362256
# Iteration # 12
# Removing WetBulb_agg3 with VIF of 208222.483363
# Iteration # 13
# Removing StnPressure_lag5 with VIF of 142344.422758
# Iteration # 14
# Removing Tavg_agg3 with VIF of 131547.581945
# Iteration # 15
# Removing StationLat with VIF of 72050.506863
# Iteration # 16
# Removing DewPoint_agg7 with VIF of 23263.379645
# Iteration # 17
# Removing WetBulb_lag5 with VIF of 22806.281555
# Iteration # 18
# Removing WetBulb_lag2 with VIF of 22667.244037
# Iteration # 19
# Removing WetBulb_lag1 with VIF of 21340.045509
# Iteration # 20
# Removing Tavg_agg7 with VIF of 17867.048509
# Iteration # 21
# Removing StnPressure_lag2 with VIF of 16372.319403
# Iteration # 22
# Removing DewPoint_agg3 with VIF of 4878.986833
# Iteration # 23
# Removing WetBulb_lag3 with VIF of 4147.274860
# Iteration # 24
# Removing Tavg_lag1 with VIF of 1266.705486
# Iteration # 25
# Removing WetBulb_lag4 with VIF of 1217.280523
# Iteration # 26
# Removing Tavg_lag5 with VIF of 758.387946
# Iteration # 27
# Removing Tmin with VIF of 705.891783
# Iteration # 28
# Removing AvgSpeed_agg7 with VIF of 688.955707
# Iteration # 29
# Removing Tavg_lag2 with VIF of 516.927742
# Iteration # 30
# Removing DewPoint_lag2 with VIF of 373.526675
# Iteration # 31
# Removing AvgSpeed_agg3 with VIF of 245.145594
# Iteration # 32
# Removing Daylight with VIF of 217.791591
# Iteration # 33
# Removing DewPoint_lag3 with VIF of 130.839000
# Iteration # 34
# Removing DewPoint_lag1 with VIF of 102.279174
# Iteration # 35
# Removing AvgSpeed with VIF of 77.027415
# Iteration # 36
# Removing AvgSpeed_lag3 with VIF of 73.309779
# Iteration # 37
# Removing Week with VIF of 52.000038
# Iteration # 38
# Removing AvgSpeed_lag5 with VIF of 42.056985
# Iteration # 39
# Removing DewPoint_lag5 with VIF of 22.005767
# Iteration # 40
# Removing AvgSpeed_lag4 with VIF of 9.848721
# Iteration # 41
# Removing WindSpeed_lag2 with VIF of 7.577222
# Iteration # 42
# Removing PrecipTotal_agg7 with VIF of 7.314681
# Iteration # 43
# Removing WindSpeed with VIF of 5.925779
# Iteration # 44
# Removing Station_dist with VIF of 5.332401
# Iteration # 45
# Complete

# %%
final_vif
# Out:
#     VIFactor           features
# 2   1.182722  PrecipTotal_lag10
# 6   1.202100   PrecipTotal_lag6
# 5   1.266959   PrecipTotal_lag5
# 3   1.290996   PrecipTotal_lag2
# 4   1.327334   PrecipTotal_lag3
# 1   1.750867               Heat
# 0   1.802777             Depart
# 11  2.374143     WnvPerc_weekly
# 8   3.917215     WindSpeed_lag1
# 7   4.157219      WindDirection
# 9   4.219817     WindSpeed_lag3
# 10  4.397370     WindSpeed_lag5

# %% [markdown]
# I am concerned how dominant PrecipTotal and WindSpeed lag columns are in the new much smaller data set.  I will continue on for now.

# %%
final_df.shape
# Out:
# (3692, 12)

# %% [markdown]
# Alright. I have gone from 77 features down to 12 by dropping 22 with very low or very high information value and eliminating the rest based on colinearity.

# %%
X_train = final_df
X_test = X_test[X_train.columns]
print(X_train.shape)
print(X_test.shape)
X_cols = final_df.columns
# Out:
# (3692, 12)
# (924, 12)

# %%
X_train
# Out:
#       Depart  Heat  PrecipTotal_lag10  PrecipTotal_lag2  PrecipTotal_lag3  \
# 1916   -10.0     1               0.00              0.32              0.00
# 2613     6.0     0               1.23              0.00              0.14
# 2022    -4.0     0               0.04              0.00              0.01
# 4363     7.0     0               0.00              0.00              0.00
# 1530    -8.0     9               0.01              0.00              0.01
# ...      ...   ...                ...               ...               ...
# 3935    -4.0     0               0.02              0.00              0.01
# 1877   -10.0     1               0.00              0.32              0.00
# 593     10.0     0               0.00              0.97              0.02
# 4529    14.0     0               0.00              0.01              0.01
# 2873     6.0     0               0.00              0.01              0.01
#
#       PrecipTotal_lag5  PrecipTotal_lag6  WindDirection  WindSpeed_lag1  \
# 1916              0.00              1.12            290             9.6
# 2613              0.01              0.00            160             3.9
# 2022              0.01              0.00            260             4.4
# 4363              0.02              0.96            170             9.2
# 1530              0.00              0.01             30             1.0
# ...                ...               ...            ...             ...
# 3935              0.01              0.01            230            10.1
# 1877              0.00              1.12            290             9.6
# 593               0.00              0.00            240             2.6
# 4529              0.00              0.01            160             6.7
# 2873              0.02              0.04             40             3.3
#
#       WindSpeed_lag3  WindSpeed_lag5  WnvPerc_weekly
# 1916             7.5             1.9        0.055794
# 2613             6.4             3.9        0.004000
# 2022             6.4             8.0        0.095930
# 4363             1.5             3.9        0.194872
# 1530             1.8             6.8        0.000000
# ...              ...             ...             ...
# 3935             5.2             3.8        0.040956
# 1877             7.5             1.9        0.055794
# 593              5.9             6.5        0.152249
# 4529            11.4             5.3        0.053672
# 2873             5.9             0.7        0.040956
#
# [3692 rows x 12 columns]

# %% [markdown]
# Now I will standardize all of the remaining features for modeling.

# %%
from sklearn.preprocessing import StandardScaler
sscale = StandardScaler()
sscale.fit(X_train)
X_train = sscale.transform(X_train)
X_test = sscale.transform(X_test)

# %% [markdown]
# Looks good. I can now export these df's for modeling.

# %%
pd.DataFrame(X_train,columns=X_cols).to_csv('X_train.csv')
pd.DataFrame(X_test,columns=X_cols).to_csv('X_test.csv')
pd.DataFrame(y_train).to_csv('y_train.csv')
pd.DataFrame(y_test).to_csv('y_test.csv')

# %% [markdown]
# I'll do a quick PCA now to inspect the principal components of the dataset.

# %%
### Calculate PCA an plot percent variance explained

from sklearn.decomposition import PCA
pca = PCA()
pca.fit(X_train)
X_pca = pca.transform(X_train)
                      
plt.subplots(figsize=(10, 6))
plt.plot(pca.explained_variance_ratio_.cumsum())
plt.ylabel('Percent Variance explained')
plt.xlabel('Principal Components')
plt.grid(axis='both')
plt.show()

# %% [markdown]
# From the PCA it looks like ~10 principal components explain 95% of the variance.  During the modelling process I probably do not need more than 10 predictors in my model.  I will try NMF also to see if I can identify key columns in the NMF components.

# %%
plt.scatter(X_pca[:,0],X_pca[:,1],c=y_train.to_numpy());
plt.ylabel('Principal component 2')
plt.xlabel('Principal component 1')
plt.title('Scatter plot of first 2 principal components\ncolored by negative(dark) or positive(light) WNV case')
# Out:
# Text(0.5, 1.0, 'Scatter plot of first 2 principal components\ncolored by negative(dark) or positive(light) WNV case')

# %% [markdown]
# The first two principal components are starting to distinguish between negative and positive WNV cases.

# %% [markdown]
# Now I will apply a simple Logistic Regression model to predict the positive WNV cases.

# %%
for dat in [X_train,X_test,y_train,y_test]:
    print(type(dat))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,roc_auc_score,\
        plot_roc_curve, plot_precision_recall_curve, precision_recall_curve,\
        make_scorer, plot_confusion_matrix
from sklearn.model_selection import GridSearchCV

logreg = LogisticRegression()
logreg_grid = GridSearchCV(logreg,param_grid={'class_weight':['balanced']},cv=5,
                          scoring = make_scorer(roc_auc_score))
logreg_grid.fit(X_train, y_train)


print('Training AUC:', roc_auc_score(y_train,logreg_grid.predict_proba(X_train)[:,1] )) 
print('Testint AUC:', roc_auc_score(y_test, logreg_grid.predict_proba(X_test)[:,1] ))
# Out:
# Training AUC: 0.7960354878572964
# Testint AUC: 0.7772734939204833

# %%
fig,ax = plt.subplots(figsize=(5,5))
plot_roc_curve(logreg_grid,X_train,y_train,ax=ax,name='Train')
plot_roc_curve(logreg_grid,X_test,y_test,ax=ax,name='Test')
plt.show()

# %%
fig,ax = plt.subplots(1,2,tight_layout=True)

plot_confusion_matrix(logreg_grid,X_train,y_train,values_format='.4g',ax=ax[0])
plot_confusion_matrix(logreg_grid,X_test,y_test,values_format='.4g',ax=ax[1])

ax[0].set_title('Training')
ax[1].set_title('Testing')

plt.show()

# %%
### Training data Precision and recall
print('Training Metrics')
print('Precision: {:.3f}'.format(237/(237+1010)))
print('Recall:    {:.3f}'.format(237/(237+71)))
print()
print('Testing Metrics')
print('Precision: {:.3f}'.format(59/(59+260)))
print('Recall:    {:.3f}'.format(59/(59+18)))
# Out:
# Training Metrics
# Precision: 0.190
# Recall:    0.769
#
# Testing Metrics
# Precision: 0.185
# Recall:    0.766

# %% [markdown]
# That looks ok.  The model is clearly not overfit and it has decent predictive power.  In the next notebook I will try to improve upon this model with more complex modelling techniques.

# %% [markdown]
# # Summary
#
# In this notebook, first I imported the cleaned and merged data set.  Next I dropped non-numeric and other extraneous columns that could not be used for prediction of the test set.
#
# I split the data, 80% into a training set and 20% into a test set.  Then I used a function to calculate the weight of evidence and information value of each predictor to the target.  I dropped predictors that had IV >0.8 or <0.01.  Next I checked for colinearity in the data set by iteratively calculating the variance inflation factor for each feature.  This process filtered the predictors down to 12 that will be used for modeling. Then I applied a standard scaler to the predictors and exported the X_train, X_test, y_train, & y_test sets out to csv files.
#
# I performed PCA on the data set, but because I have reduced the features so much much with the previously mentioned steps, there is not much value in it.  The first two principal components do not seperate out the positive cases from the negative.
#
# Finally I applied a logistic regression to the training data set.  I did not attempt any hyper parameter tuning and the result was pretty good.  I will attempt to improve upon this with more advanced ML techniques in the next notebook.
