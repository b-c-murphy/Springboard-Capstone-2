# %% [markdown]
# # Preprocessing and Feature Engineering
#
# In this notebook I will create a clean dataset ready to model through feature engineering and standardization.
#
# First load the data from EDA, and clean up any extraneous columns that will not be used in prediction.  Then I will split the data into predictors and target.
#
# Next I will perform PCA to see the principal components of the data.  The principal components may be used as input to the modelling phase.
#
# Finally I will perform a train-test split and apply a basic logistic regression model to the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import traceback

# %%
random_seed = 27

# %%
train = pd.read_csv('train_w_aggregated_weather.csv',index_col=0)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4616 entries, 0 to 4615
# Columns: 110 entries, Date to Daylight
# dtypes: float64(82), int64(22), object(6)
# memory usage: 3.9+ MB

# %%
print('Length of data:',train.shape[0])
print('Duplicate Traps & dates:',train.duplicated(subset=['Date','Trap']).sum())
# Out:
# Length of data: 4616
# Duplicate Traps & dates: 0

# %% [markdown]
# Looks good. I will clean up (drop) some columns that can't be used or will not be available for prediction.

# %%
### drop mosquito species columns, won't have that for predicting 
train = train.drop(['RESTUANS','PIPIENS','SALINARIUS','TERRITANS',\
                    'TARSALIS','ERRATICUS'],axis=1)

# %%
### Drop extraneous columns that won't be used in modeling
train = train.drop(['Date','Trap','Address','Block','Street',\
                    'AddressNumberAndStreet','Latitude','Longitude',\
                   'AddressAccuracy','Station'],axis=1)

# %%
### Drop CodeSum string columns
#train = train.drop(['CodeSum_3days','CodeSum_7days','CodeSum_14days']\
                   #,axis=1)
train = train.drop('CodeSum',axis=1)

# %%
### Finally drop the number of mosquitos column and Yearly columns
### as this will not be available for prediction
train = train.drop('NumMosquitos',axis=1)
train = train.drop(['Year','WnvPerc_yearly'],axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4616 entries, 0 to 4615
# Data columns (total 90 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   WnvPresent         4616 non-null   float64
#  1   Month              4616 non-null   int64
#  2   Week               4616 non-null   int64
#  3   WnvPerc_monthly    4616 non-null   float64
#  4   WnvPerc_weekly     4616 non-null   float64
#  5   Station_dist       4616 non-null   float64
#  6   Tmax               4616 non-null   int64
#  7   Tmin               4616 non-null   int64
#  8   Tavg               4616 non-null   int64
#  9   Depart             4616 non-null   float64
#  10  DewPoint           4616 non-null   int64
#  11  WetBulb            4616 non-null   int64
#  12  Heat               4616 non-null   int64
#  13  Cool               4616 non-null   int64
#  14  PrecipTotal        4616 non-null   float64
#  15  StnPressure        4616 non-null   float64
#  16  SeaLevel           4616 non-null   float64
#  17  AvgSpeed           4616 non-null   float64
#  18  WindDirection      4616 non-null   int64
#  19  WindSpeed          4616 non-null   float64
#  20  StationLat         4616 non-null   float64
#  21  StationLong        4616 non-null   float64
#  22  StationElev_ft     4616 non-null   int64
#  23  Tavg_lag1          4616 non-null   float64
#  24  Tavg_lag2          4616 non-null   float64
#  25  Tavg_lag3          4616 non-null   float64
#  26  Tavg_lag4          4616 non-null   float64
#  27  Tavg_lag5          4616 non-null   float64
#  28  Tavg_lag6          4616 non-null   float64
#  29  Tavg_lag7          4616 non-null   float64
#  30  DewPoint_lag1      4616 non-null   float64
#  31  DewPoint_lag2      4616 non-null   float64
#  32  DewPoint_lag3      4616 non-null   float64
#  33  DewPoint_lag4      4616 non-null   float64
#  34  DewPoint_lag5      4616 non-null   float64
#  35  DewPoint_lag6      4616 non-null   float64
#  36  DewPoint_lag7      4616 non-null   float64
#  37  WetBulb_lag1       4616 non-null   float64
#  38  WetBulb_lag2       4616 non-null   float64
#  39  WetBulb_lag3       4616 non-null   float64
#  40  WetBulb_lag4       4616 non-null   float64
#  41  WetBulb_lag5       4616 non-null   float64
#  42  WetBulb_lag6       4616 non-null   float64
#  43  WetBulb_lag7       4616 non-null   float64
#  44  WindSpeed_lag1     4616 non-null   float64
#  45  WindSpeed_lag2     4616 non-null   float64
#  46  WindSpeed_lag3     4616 non-null   float64
#  47  WindSpeed_lag4     4616 non-null   float64
#  48  WindSpeed_lag5     4616 non-null   float64
#  49  AvgSpeed_lag1      4616 non-null   float64
#  50  AvgSpeed_lag2      4616 non-null   float64
#  51  AvgSpeed_lag3      4616 non-null   float64
#  52  AvgSpeed_lag4      4616 non-null   float64
#  53  AvgSpeed_lag5      4616 non-null   float64
#  54  StnPressure_lag1   4616 non-null   float64
#  55  StnPressure_lag2   4616 non-null   float64
#  56  StnPressure_lag3   4616 non-null   float64
#  57  StnPressure_lag4   4616 non-null   float64
#  58  StnPressure_lag5   4616 non-null   float64
#  59  StnPressure_lag6   4616 non-null   float64
#  60  StnPressure_lag7   4616 non-null   float64
#  61  PrecipTotal_lag1   4616 non-null   float64
#  62  PrecipTotal_lag2   4616 non-null   float64
#  63  PrecipTotal_lag3   4616 non-null   float64
#  64  PrecipTotal_lag4   4616 non-null   float64
#  65  PrecipTotal_lag5   4616 non-null   float64
#  66  PrecipTotal_lag6   4616 non-null   float64
#  67  PrecipTotal_lag7   4616 non-null   float64
#  68  PrecipTotal_lag8   4616 non-null   float64
#  69  PrecipTotal_lag9   4616 non-null   float64
#  70  PrecipTotal_lag10  4616 non-null   float64
#  71  PrecipTotal_lag11  4616 non-null   float64
#  72  PrecipTotal_lag12  4616 non-null   float64
#  73  PrecipTotal_lag13  4616 non-null   float64
#  74  PrecipTotal_lag14  4616 non-null   float64
#  75  Tavg_agg3          4616 non-null   float64
#  76  PrecipTotal_agg3   4616 non-null   float64
#  77  DewPoint_agg3      4616 non-null   float64
#  78  WetBulb_agg3       4616 non-null   float64
#  79  StnPressure_agg3   4616 non-null   float64
#  80  SeaLevel_agg3      4616 non-null   float64
#  81  AvgSpeed_agg3      4616 non-null   float64
#  82  Tavg_agg7          4616 non-null   float64
#  83  PrecipTotal_agg7   4616 non-null   float64
#  84  DewPoint_agg7      4616 non-null   float64
#  85  WetBulb_agg7       4616 non-null   float64
#  86  StnPressure_agg7   4616 non-null   float64
#  87  SeaLevel_agg7      4616 non-null   float64
#  88  AvgSpeed_agg7      4616 non-null   float64
#  89  Daylight           4616 non-null   float64
# dtypes: float64(79), int64(11)
# memory usage: 3.2 MB

# %% [markdown]
# Looks great the data set is all numeric and there are no nulls to be found.  Now I will split the train and test data.

# %%
### Split into X and y
y = train['WnvPresent']
X = train.drop('WnvPresent',axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify=y,\
                                 test_size=.2,random_state=random_seed)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
print(type(X_train))
# Out:
# (3692, 89)
# (924, 89)
# (3692,)
# (924,)
# <class 'pandas.core.frame.DataFrame'>

# %%
print('Testing Fraction positive:  {:.3f} '.format(y_test.sum()/y_test.shape[0]))
print('Training Fraction positive: {:.3f}'.format(y_train.sum()/y_train.shape[0]))
# Out:
# Testing Fraction positive:  0.083
# Training Fraction positive: 0.083

# %% [markdown]
# That data are now split into testing and training set, and each now has the same proportion of positive cases.

# %% [markdown]
# Now I will implement Rahul's function for calculating the predictive power of each feature.  The function calculates weight of evidence and Information value for each feature.  The features with little information value or suspiciously high information value will be dropped.
# ___
# After that I will check the colinearity of the features in the training data set and drop any features that are highly correlative to others. (Helping to reduce model overfitting to the training set).

# %%
### Function from Rahul to calculate the Information Value (IV) of each feature
### I will go through each line and add my own personal comments so 
### that I can understand what this function is doing. 


max_bin = 20
force_bin = 3
import pandas.core.algorithms as algos
import scipy.stats.stats as stats


# define a binning function
### this function is for binning and calculating the Weight of Evidence 
### for the target and the Information Value for the feature
### and the In
def mono_bin(Y, X, n = max_bin):    
    ### create new dataframe of series feature and series y
    df1 = pd.DataFrame({"X": X, "Y": Y})
    
    ### check to see if any nulls in feature and seperate nulls out
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    #print("justmiss", justmiss)
    #print("notmiss", notmiss)
    
    
    ### while loop until Spearman correlation coefficient is between [-1,1]
    ### Finding minumum bin size that results in 'abs(r)' of >1???
    
    r = 0
    while np.abs(r) < 1:
        ### Try creation of new dataframe with max or less bin size 'n'
        ### create dataframe with feature, target and binned feature 
        ### create 'd2' group by object on 'Bucket'
        ### calculate Spearman correlation 'r' and p-value from mean of feature and target
        ### If exception reduce bin number by one and try again
        ### Effectively finding the max bin number that can be used 
        ### for calculating WOE
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y,\
                               "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
                             
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            #print("I am here 1",r, n,len(d2))
            n = n - 1 
            
            
        except Exception as e:
            n = n - 1
            #print("I am here e",n)

    ### If length of d2 is 1 (ie 1 bucket for all of feature) do this
    if len(d2) == 1:
        #print("I am second step ",r, n)
        
        ### force 'n' to 3 and calculate quantiles of feature from (0,0.5,1) 
        ### to be used as bins, if not 3 unique because of heavily skewed data
        ### manually create bin
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
            
        ### Create new dataframe bucketed by manual bins
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    ### Create new dataframe from aggregating the binned dataframe
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        #print(justmiss.count().Y)
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    ### add more features to d3 describing the 'events' of the target
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    print(np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT))
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    #print("hi",d3.IV )
    d3 = d3.reset_index(drop=True)
    
    return(d3)

def data_vars(df1, target):
    import traceback
    
    
    ### Extract raw traceback from error in one of the two sub functions
    ### assign traceback elemnts to variables
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    
    ###
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    
    ### get column names from df1
    x = df1.dtypes.index
    
    count = -1
    ### Loop through columns
    for i in x:
        print(i)
        if i.upper() not in (final.upper()):
            ### test if numeric and not a one-hot encoding
            if np.issubdtype(df1[i], np.number) and len(pd.Series.unique(df1[i])) > 2:
                #print("Number and unique value greater than 2")
                ###  pass target and feature to 'mono_bin'
                conv = mono_bin(target, df1[i])
                
                ### assign feature name to 'conv'
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                #print("I am here 2")
                ###  pass target and feature to 'char_bin'
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1

            ### First time run through the loop where count==0,
            ### create new df from current
            if count == 0:
                iv_df = conv
            ### on subsequent loops append rows to bottom of 'iv_df'
            ### of next feature and scoring calcs
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    ### aggregate 'iv_df' taking the maximum ?correlation? score 
    ### for each feature and creating a new summary df with columns 
    ### 'VAR_NAME' & 'IV'
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    ### return detailed df with all computed features
    ### and summary of only max values and feature names
    return(iv_df,iv)

# %%
iv_df, iv = data_vars(X_train,y_train)
# Out:
# Month
# 0    0.023442
# 1   -0.063943
# dtype: float64
# Week
# 0   -0.695860
# 1    0.525263
# dtype: float64
# WnvPerc_monthly
# 0   -1.623266
# 1    0.041682
# 2    0.902687
# dtype: float64
# WnvPerc_weekly
# 0        -inf
# 1   -1.541127
# 2   -0.625741
# 3    0.090856
# 4    0.771610
# 5    1.150368
# dtype: float64
# Station_dist
# C:\Users\blain\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0    0.187484
# 1    0.148937
# 2   -0.128418
# 3   -0.279187
# dtype: float64
# Tmax
# 0   -0.171726
# 1    0.077307
# 2    0.078511
# dtype: float64
# Tmin
# 0   -0.434256
# 1    0.330288
# dtype: float64
# Tavg
# 0   -0.140065
# 1    0.141578
# dtype: float64
# Depart
# 0   -0.194097
# 1    0.191029
# dtype: float64
# DewPoint
# 0   -0.489503
# 1   -0.240641
# 2    0.536245
# dtype: float64
# WetBulb
# 0   -0.925829
# 1   -0.217185
# 2    0.045339
# 3    0.217189
# 4    0.314616
# 5    0.436380
# dtype: float64
# Heat
# 0    0.117716
# 1   -1.318889
# dtype: float64
# Cool
# 0   -0.140065
# 1    0.141578
# dtype: float64
# PrecipTotal
# 0    0.004536
# 1   -0.242343
# dtype: float64
# StnPressure
# 0    0.037385
# 1   -0.039403
# dtype: float64
# SeaLevel
# 0   -0.038266
# 1    0.039788
# dtype: float64
# AvgSpeed
# 0    0.263406
# 1    0.019128
# 2   -0.366412
# dtype: float64
# WindDirection
# 0    -0.796378
# 1     0.493363
# 2     0.011293
# 3    -0.247094
# 4     0.199489
# 5    -0.679061
# 6    -0.684176
# 7     0.483594
# 8    -0.747438
# 9     0.924477
# 10    0.121780
# 11    0.212393
# 12         NaN
# 13    0.401042
# 14   -0.886700
# 15   -0.744972
# 16    0.052886
# dtype: float64
# WindSpeed
# 0    0.285950
# 1    0.269736
# 2   -0.341078
# 3   -0.448195
# dtype: float64
# StationLat
# StationLong
# StationElev_ft
# Tavg_lag1
# 0   -0.634430
# 1   -0.283685
# 2    0.269242
# 3    0.442674
# dtype: float64
# Tavg_lag2
# 0   -0.523898
# 1   -0.112029
# 2   -0.097210
# 3    0.038962
# 4    0.245360
# 5    0.399165
# dtype: float64
# Tavg_lag3
# 0    -0.812112
# 1    -0.483505
# 2     0.094129
# 3     1.123748
# 4    -1.147140
# 5     0.084420
# 6          NaN
# 7    -0.439762
# 8    -0.769364
# 9     0.199489
# 10    0.538997
# 11    0.008695
# 12   -0.770869
# 13    0.767473
# 14   -0.528401
# dtype: float64
# Tavg_lag4
# 0   -0.040289
# 1    0.042541
# dtype: float64
# Tavg_lag5
# 0   -0.306365
# 1    0.263909
# dtype: float64
# Tavg_lag6
# 0   -0.279461
# 1    0.226905
# dtype: float64
# Tavg_lag7
# 0   -0.744561
# 1    0.064276
# 2    0.154914
# 3    0.472635
# dtype: float64
# DewPoint_lag1
# 0   -0.665372
# 1   -0.502009
# 2    0.227353
# 3    0.640596
# dtype: float64
# DewPoint_lag2
# 0   -0.239819
# 1   -0.175732
# 2    0.372188
# dtype: float64
# DewPoint_lag3
# 0   -0.105557
# 1    0.123019
# dtype: float64
# DewPoint_lag4
# 0   -0.030850
# 1    0.034459
# dtype: float64
# DewPoint_lag5
# 0   -0.535505
# 1    0.056741
# 2    0.344822
# dtype: float64
# DewPoint_lag6
# 0   -0.271582
# 1    0.258633
# dtype: float64
# DewPoint_lag7
# 0   -0.239505
# 1    0.207458
# dtype: float64
# WetBulb_lag1
# 0   -0.656343
# 1   -0.643263
# 2    0.396670
# 3    0.614711
# dtype: float64
# WetBulb_lag2
# 0   -0.417749
# 1   -0.058634
# 2    0.436510
# dtype: float64
# WetBulb_lag3
# 0   -0.160843
# 1   -0.075289
# 2    0.252379
# dtype: float64
# WetBulb_lag4
# 0   -0.256848
# 1    0.051069
# 2    0.190273
# dtype: float64
# WetBulb_lag5
# 0   -0.790650
# 1    0.206047
# 2    0.320326
# dtype: float64
# WetBulb_lag6
# 0   -1.056443
# 1   -0.117279
# 2   -0.033384
# 3   -0.023654
# 4    0.367283
# 5    0.476645
# dtype: float64
# WetBulb_lag7
# 0   -0.397031
# 1   -0.187982
# 2    0.440451
# dtype: float64
# WindSpeed_lag1
# 0    0.146001
# 1    0.107859
# 2   -0.094392
# 3   -0.213119
# dtype: float64
# WindSpeed_lag2
# 0   -0.179484
# 1    0.168953
# dtype: float64
# WindSpeed_lag3
# 0    0.194335
# 1    0.144483
# 2   -0.447848
# dtype: float64
# WindSpeed_lag4
# 0   -0.071502
# 1    0.069135
# dtype: float64
# WindSpeed_lag5
# 0    0.112842
# 1   -0.136372
# dtype: float64
# AvgSpeed_lag1
# 0   -0.058476
# 1    0.057315
# dtype: float64
# AvgSpeed_lag2
# 0    0.033089
# 1   -0.039312
# dtype: float64
# AvgSpeed_lag3
# 0    0.178759
# 1    0.080585
# 2   -0.318329
# dtype: float64
# AvgSpeed_lag4
# 0    0.224785
# 1   -0.099774
# 2   -0.172698
# dtype: float64
# AvgSpeed_lag5
# 0    0.263139
# 1   -0.356593
# dtype: float64
# StnPressure_lag1
# 0    0.060567
# 1   -0.067290
# dtype: float64
# StnPressure_lag2
# 0   -0.089366
# 1    0.083344
# dtype: float64
# StnPressure_lag3
# 0   -0.195023
# 1    0.186652
# dtype: float64
# StnPressure_lag4
# 0   -0.421474
# 1   -0.076601
# 2    0.374842
# dtype: float64
# StnPressure_lag5
# 0   -0.207873
# 1    0.042457
# 2    0.065784
# 3    0.129263
# dtype: float64
# StnPressure_lag6
# 0    0.038559
# 1   -0.040592
# dtype: float64
# StnPressure_lag7
# 0   -0.033133
# 1    0.034268
# dtype: float64
# PrecipTotal_lag1
# 0   -0.019995
# 1    0.459772
# dtype: float64
# PrecipTotal_lag2
# 0   -0.046094
# 1    0.763559
# dtype: float64
# PrecipTotal_lag3
# 0   -0.123284
# 1    0.233681
# dtype: float64
# PrecipTotal_lag4
# 0    0.014586
# 1        -inf
# dtype: float64
# PrecipTotal_lag5
# 0   -0.051223
# 1    1.266849
# dtype: float64
# C:\Users\blain\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# PrecipTotal_lag6
# 0   -0.183224
# 1    0.256242
# dtype: float64
# PrecipTotal_lag7
# 0    0.012020
# 1   -0.795133
# dtype: float64
# PrecipTotal_lag8
# 0   -0.006639
# 1    0.250133
# dtype: float64
# PrecipTotal_lag9
# 0   -0.008952
# 1    0.787276
# dtype: float64
# PrecipTotal_lag10
# 0    0.020642
# 1   -0.518049
# dtype: float64
# PrecipTotal_lag11
# 0    0.000296
# 1        -inf
# dtype: float64
# PrecipTotal_lag12
# 0   -0.002690
# 1    0.123116
# dtype: float64
# PrecipTotal_lag13
# 0   -0.014816
# 1    0.588425
# dtype: float64
# C:\Users\blain\Anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# PrecipTotal_lag14
# 0   -0.037260
# 1    1.180319
# dtype: float64
# Tavg_agg3
# 0   -0.875981
# 1   -0.078759
# 2    0.274617
# 3    0.342863
# dtype: float64
# PrecipTotal_agg3
# 0    0.065453
# 1   -0.070556
# dtype: float64
# DewPoint_agg3
# 0   -0.810668
# 1   -0.701876
# 2   -0.433315
# 3    0.006641
# 4    0.315043
# 5    0.357660
# 6    0.688336
# dtype: float64
# WetBulb_agg3
# 0   -1.028914
# 1   -0.370071
# 2    0.366908
# 3    0.526286
# dtype: float64
# StnPressure_agg3
# 0    0.009229
# 1   -0.009630
# dtype: float64
# SeaLevel_agg3
# 0   -0.009255
# 1    0.009715
# dtype: float64
# AvgSpeed_agg3
# 0    0.203051
# 1    0.056527
# 2   -0.321808
# dtype: float64
# Tavg_agg7
# 0   -0.737107
# 1    0.177510
# 2    0.324935
# dtype: float64
# PrecipTotal_agg7
# 0   -0.153198
# 1   -0.088193
# 2   -0.041567
# 3    0.247403
# dtype: float64
# DewPoint_agg7
# 0   -0.968939
# 1   -0.815989
# 2   -0.292105
# 3    0.154369
# 4    0.353640
# 5    0.733639
# dtype: float64
# WetBulb_agg7
# 0   -0.794763
# 1   -0.708218
# 2    0.406148
# 3    0.516555
# dtype: float64
# StnPressure_agg7
# 0   -0.336964
# 1    0.264218
# dtype: float64
# SeaLevel_agg7
# 0   -0.372491
# 1    0.293447
# dtype: float64
# AvgSpeed_agg7
# 0    0.326575
# 1    0.279341
# 2   -0.303115
# 3   -0.547725
# dtype: float64
# Daylight
# 0    0.531929
# 1   -1.063895
# dtype: float64

# %%
iv.sort_values('IV',ascending=False).head(20)
# Out:
#            VAR_NAME        IV
# 87  WnvPerc_monthly  0.992365
# 88   WnvPerc_weekly  0.727134
# 9          Daylight  0.540767
# 69             Week  0.354774
# 13    DewPoint_agg7  0.353727
# 62        Tavg_lag3  0.342719
# 72     WetBulb_agg7  0.336424
# 71     WetBulb_agg3  0.334183
# 73     WetBulb_lag1  0.320081
# 80    WindDirection  0.282884
# 14    DewPoint_lag1  0.275164
# 12    DewPoint_agg3  0.272779
# 77     WetBulb_lag5  0.203553
# 11         DewPoint  0.198555
# 78     WetBulb_lag6  0.194171
# 58        Tavg_agg3  0.190697
# 59        Tavg_agg7  0.185690
# 70          WetBulb  0.180307
# 66        Tavg_lag7  0.176883
# 60        Tavg_lag1  0.171785

# %% [markdown]
# Looks good. Now to filter out features with very low (0.01) and very high (0.8) information value.

# %%
features = list(iv[(iv['IV'] >= 0.01) & (iv['IV'] <= 0.8)]['VAR_NAME'])
X2 = X_train[features]

display(X2.shape)

X2.head()
# Out:
# (3692, 64)
#       AvgSpeed  AvgSpeed_agg3  AvgSpeed_agg7  AvgSpeed_lag3  AvgSpeed_lag4  \
# 1916      10.4      11.500000       8.914286            7.7            7.4
# 2613      10.6       8.366667       7.971429            9.2            7.0
# 2022       7.3       6.633333       8.242857            8.0           10.1
# 4368       6.0       7.566667       6.971429            4.6            8.7
# 1530       9.2       8.500000       7.928571            6.6            6.8
#
#       AvgSpeed_lag5  Cool   Daylight  Depart  DewPoint  ...  WetBulb_lag5  \
# 1916            5.2     0  14.900000   -10.0        52  ...          60.0
# 2613            5.8    13  15.200000     6.0        61  ...          60.0
# 2022            8.6     5  14.483333    -4.0        54  ...          64.0
# 4368            5.8     9  12.950000     7.0        55  ...          69.0
# 1530            8.3     0  15.016667    -8.0        47  ...          54.0
#
#       WetBulb_lag6  WetBulb_lag7  WindDirection  WindSpeed  WindSpeed_lag1  \
# 1916          67.0          68.0            290       10.1             9.6
# 2613          59.0          63.0            160        9.2             3.9
# 2022          64.0          64.0            260        6.2             4.4
# 4368          68.0          71.0            170        4.3             9.2
# 1530          63.0          58.0             30        8.3             1.0
#
#       WindSpeed_lag2  WindSpeed_lag3  WindSpeed_lag5  WnvPerc_weekly
# 1916            10.0             7.5             1.9        0.055794
# 2613             7.2             6.4             3.9        0.004000
# 2022             4.2             6.4             8.0        0.095930
# 4368             6.4             1.5             3.9        0.194872
# 1530             2.9             1.8             6.8        0.000000
#
# [5 rows x 64 columns]

# %% [markdown]
# Excellent. I have reduced the number of features from 89  to 64.  Now I am sure some of the features are highly correlated.  I will asses the colinearity of the data and then remove any highly correlative features.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def iterate_vif(df, vif_threshold=5, max_vif=6):
    count = 0
    while max_vif > vif_threshold:
        count += 1
        print("Iteration # "+str(count))
        
        ### Create data frame with features column and 
        ### variance inflation factor column
        vif = pd.DataFrame()
        vif["VIFactor"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
        vif["features"] = df.columns
        
        
        
        if vif['VIFactor'].max() > vif_threshold:
            print('Removing %s with VIF of %f' % (vif[vif['VIFactor'] == vif['VIFactor'].max()]['features'].values[0], vif['VIFactor'].max()))
            df = df.drop(vif[vif['VIFactor'] == vif['VIFactor'].max()]['features'].values[0], axis=1)
            max_vif = vif['VIFactor'].max()
        else:
            print('Complete')
            return df, vif.sort_values('VIFactor')

# %%
X1 = X2._get_numeric_data()
final_df, final_vif = iterate_vif(X1)
# Out:
# Iteration # 1
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing Cool with VIF of inf
# Iteration # 2
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing DewPoint with VIF of inf
# Iteration # 3
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing StationElev_ft with VIF of inf
# Iteration # 4
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing Tavg with VIF of inf
# Iteration # 5
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing WetBulb with VIF of inf
# Iteration # 6
# C:\Users\blain\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Removing WetBulb_agg3 with VIF of inf
# Iteration # 7
# Removing StationLong with VIF of 66710080.867397
# Iteration # 8
# Removing SeaLevel_agg7 with VIF of 3572909.301188
# Iteration # 9
# Removing WetBulb_agg7 with VIF of 1427987.603701
# Iteration # 10
# Removing Tavg_agg3 with VIF of 1397886.107790
# Iteration # 11
# Removing StnPressure_agg7 with VIF of 1208320.545539
# Iteration # 12
# Removing StnPressure_lag4 with VIF of 767815.910004
# Iteration # 13
# Removing Tavg_agg7 with VIF of 305583.213897
# Iteration # 14
# Removing StnPressure_lag5 with VIF of 196744.061058
# Iteration # 15
# Removing DewPoint_agg7 with VIF of 109501.321137
# Iteration # 16
# Removing StationLat with VIF of 77305.480551
# Iteration # 17
# Removing Daylight with VIF of 45832.928437
# Iteration # 18
# Removing WetBulb_lag5 with VIF of 25110.343107
# Iteration # 19
# Removing WetBulb_lag2 with VIF of 24913.118987
# Iteration # 20
# Removing WetBulb_lag6 with VIF of 24656.193309
# Iteration # 21
# Removing WetBulb_lag1 with VIF of 22140.987302
# Iteration # 22
# Removing WetBulb_lag7 with VIF of 20842.450951
# Iteration # 23
# Removing WetBulb_lag3 with VIF of 18659.666078
# Iteration # 24
# Removing DewPoint_agg3 with VIF of 5058.912356
# Iteration # 25
# Removing StnPressure_lag3 with VIF of 1906.493791
# Iteration # 26
# Removing WetBulb_lag4 with VIF of 1640.594987
# Iteration # 27
# Removing Tavg_lag1 with VIF of 1470.401965
# Iteration # 28
# Removing Tavg_lag5 with VIF of 1411.973548
# Iteration # 29
# Removing AvgSpeed_agg7 with VIF of 889.886231
# Iteration # 30
# Removing Tavg_lag3 with VIF of 859.295572
# Iteration # 31
# Removing DewPoint_lag6 with VIF of 757.964543
# Iteration # 32
# Removing Tavg_lag7 with VIF of 732.597802
# Iteration # 33
# Removing Tavg_lag2 with VIF of 547.094557
# Iteration # 34
# Removing Tmin with VIF of 510.414452
# Iteration # 35
# Removing Tavg_lag6 with VIF of 461.256167
# Iteration # 36
# Removing DewPoint_lag2 with VIF of 390.218390
# Iteration # 37
# Removing Tmax with VIF of 280.599057
# Iteration # 38
# Removing AvgSpeed_agg3 with VIF of 266.032462
# Iteration # 39
# Removing DewPoint_lag5 with VIF of 148.931596
# Iteration # 40
# Removing DewPoint_lag1 with VIF of 136.675882
# Iteration # 41
# Removing AvgSpeed_lag3 with VIF of 77.647131
# Iteration # 42
# Removing AvgSpeed with VIF of 77.343823
# Iteration # 43
# Removing Week with VIF of 71.262271
# Iteration # 44
# Removing DewPoint_lag3 with VIF of 58.749297
# Iteration # 45
# Removing AvgSpeed_lag5 with VIF of 42.428496
# Iteration # 46
# Removing DewPoint_lag7 with VIF of 22.357874
# Iteration # 47
# Removing AvgSpeed_lag4 with VIF of 10.373698
# Iteration # 48
# Removing WindSpeed_lag2 with VIF of 7.657160
# Iteration # 49
# Removing PrecipTotal_agg7 with VIF of 7.327725
# Iteration # 50
# Removing WindSpeed with VIF of 5.957397
# Iteration # 51
# Removing Station_dist with VIF of 5.582327
# Iteration # 52
# Complete

# %%
final_vif
# Out:
#     VIFactor           features
# 2   1.193506  PrecipTotal_lag10
# 7   1.201611   PrecipTotal_lag6
# 3   1.237607  PrecipTotal_lag14
# 6   1.266486   PrecipTotal_lag5
# 4   1.298882   PrecipTotal_lag2
# 5   1.326320   PrecipTotal_lag3
# 1   1.752037               Heat
# 0   1.827275             Depart
# 12  2.418495     WnvPerc_weekly
# 9   3.934668     WindSpeed_lag1
# 8   4.163696      WindDirection
# 10  4.351770     WindSpeed_lag3
# 11  4.542308     WindSpeed_lag5

# %% [markdown]
# I am concerned how dominant PrecipTotal and WindSpeed lag columns are in the new much smaller data set.  I will continue on for now.

# %%
final_df.shape
# Out:
# (3692, 13)

# %% [markdown]
# Alright. I have gone from 64 features down to 13 by dropping based on colinearity.

# %%
X_train = final_df
X_test = X_test[X_train.columns]
print(X_train.shape)
print(X_test.shape)
X_cols = final_df.columns
# Out:
# (3692, 13)
# (924, 13)

# %%
X_train
# Out:
#       Depart  Heat  PrecipTotal_lag10  PrecipTotal_lag14  PrecipTotal_lag2  \
# 1916   -10.0     1               0.00               0.00              0.32
# 2613     6.0     0               1.23               0.03              0.00
# 2022    -4.0     0               0.04               0.00              0.00
# 4368     7.0     0               0.00               0.00              0.00
# 1530    -8.0     9               0.01               0.00              0.00
# ...      ...   ...                ...                ...               ...
# 3933    -4.0     0               0.02               0.00              0.00
# 1877   -10.0     1               0.00               0.00              0.32
# 593     10.0     0               0.00               0.01              0.97
# 4529    14.0     0               0.00               0.01              0.00
# 2873     6.0     0               0.00               0.00              0.01
#
#       PrecipTotal_lag3  PrecipTotal_lag5  PrecipTotal_lag6  WindDirection  \
# 1916              0.00              0.00              1.12            290
# 2613              0.14              0.01              0.00            160
# 2022              0.01              0.01              0.00            260
# 4368              0.00              0.02              0.96            170
# 1530              0.01              0.00              0.01             30
# ...                ...               ...               ...            ...
# 3933              0.01              0.01              0.01            230
# 1877              0.00              0.00              1.12            290
# 593               0.02              0.00              0.00            240
# 4529              0.00              0.00              0.00            160
# 2873              0.01              0.02              0.04             40
#
#       WindSpeed_lag1  WindSpeed_lag3  WindSpeed_lag5  WnvPerc_weekly
# 1916             9.6             7.5             1.9        0.055794
# 2613             3.9             6.4             3.9        0.004000
# 2022             4.4             6.4             8.0        0.095930
# 4368             9.2             1.5             3.9        0.194872
# 1530             1.0             1.8             6.8        0.000000
# ...              ...             ...             ...             ...
# 3933            10.1             5.2             3.8        0.040956
# 1877             9.6             7.5             1.9        0.055794
# 593              2.6             5.9             6.5        0.152249
# 4529             8.7             9.7             4.7        0.053672
# 2873             3.3             5.9             0.7        0.040956
#
# [3692 rows x 13 columns]

# %% [markdown]
# Now I will standardize all of the remaining features for modeling.

# %%
from sklearn.preprocessing import StandardScaler
sscale = StandardScaler()
sscale.fit(X_train)
X_train = sscale.transform(X_train)
X_test = sscale.transform(X_test)

# %% [markdown]
# Looks good. I can now export these df's for modeling.

# %%
pd.DataFrame(X_train,columns=X_cols).to_csv('X_train.csv')
pd.DataFrame(X_test,columns=X_cols).to_csv('X_test.csv')
pd.DataFrame(y_train).to_csv('y_train.csv')
pd.DataFrame(y_test).to_csv('y_test.csv')

# %% [markdown]
# I'll do a quick PCA now to inspect the principal components of the dataset.

# %%
### Calculate PCA an plot percent variance explained

from sklearn.decomposition import PCA
pca = PCA()
pca.fit(X_train)
X_pca = pca.transform(X_train)
                      
plt.subplots(figsize=(10, 6))
plt.plot(pca.explained_variance_ratio_.cumsum())
plt.ylabel('Percent Variance explained')
plt.xlabel('Principal Components')
plt.grid(axis='both')
plt.show()

# %% [markdown]
# From the PCA it looks like ~10 principal components explain 95% of the variance.  During the modelling process I probably do not need more than 10 predictors in my model.  I will try NMF also to see if I can identify key columns in the NMF components.

# %%
plt.scatter(X_pca[:,0],X_pca[:,1],c=y_train.to_numpy());
plt.ylabel('Principal component 2')
plt.xlabel('Principal component 1')
plt.title('Scatter plot of first 2 principal components\ncolored by negative(dark) or positive(light) WNV case')
# Out:
# Text(0.5, 1.0, 'Scatter plot of first 2 principal components\ncolored by negative(dark) or positive(light) WNV case')

# %% [markdown]
# The first two principal components don't distinguish between negative and positive WNV cases, but according to the cumulative variance curve above I wouldn't expect them to.

# %% [markdown]
# Now I will apply a simple Logistic Regression model to predict the positive WNV cases.

# %%
for dat in [X_train,X_test,y_train,y_test]:
    print(type(dat))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,roc_auc_score,\
        plot_roc_curve, plot_precision_recall_curve, precision_recall_curve,\
        make_scorer, plot_confusion_matrix
from sklearn.model_selection import GridSearchCV

logreg = LogisticRegression()
logreg_grid = GridSearchCV(logreg,param_grid={'class_weight':['balanced']},cv=5,
                          scoring = make_scorer(roc_auc_score))
logreg_grid.fit(X_train, y_train)


print('Training AUC:', roc_auc_score(y_train,logreg_grid.predict_proba(X_train)[:,1] )) 
print('Testint AUC:', roc_auc_score(y_test, logreg_grid.predict_proba(X_test)[:,1] ))
# Out:
# Training AUC: 0.7949335682048447
# Testint AUC: 0.7770281666385562

# %%
fig,ax = plt.subplots(figsize=(5,5))
plot_roc_curve(logreg_grid,X_train,y_train,ax=ax,name='Train')
plot_roc_curve(logreg_grid,X_test,y_test,ax=ax,name='Test')
plt.show()

# %%
fig,ax = plt.subplots(1,2,tight_layout=True)

plot_confusion_matrix(logreg_grid,X_train,y_train,values_format='.4g',ax=ax[0])
plot_confusion_matrix(logreg_grid,X_test,y_test,values_format='.4g',ax=ax[1])

ax[0].set_title('Training')
ax[1].set_title('Testing')

plt.show()

# %%
### Training data Precision and recall
print('Training Metrics')
print('Precision: {:.3f}'.format(237/(237+1010)))
print('Recall:    {:.3f}'.format(237/(237+71)))
print()
print('Testing Metrics')
print('Precision: {:.3f}'.format(59/(59+260)))
print('Recall:    {:.3f}'.format(59/(59+18)))
# Out:
# Training Metrics
# Precision: 0.190
# Recall:    0.769
#
# Testing Metrics
# Precision: 0.185
# Recall:    0.766

# %% [markdown]
# That looks ok.  Judging by the ROC curves the model is not overfit and it has decent predictive power.  The model recall is pretty good, which is important given the context of this project.  In the next notebook I will try to improve upon this model with more complex modelling techniques.

# %% [markdown]
# # Summary
#
# In this notebook, first I imported the cleaned and merged data set.  Next I dropped non-numeric and other extraneous columns that could not be used for prediction of the test set.
#
# I split the data, 80% into a training set and 20% into a test set.  Then I used a function to calculate the weight of evidence and information value of each predictor to the target.  I dropped predictors that had IV >0.8 or <0.01.  Next I checked for colinearity in the data set by iteratively calculating the variance inflation factor for each feature.  This process filtered the predictors down to 12 that will be used for modeling. Then I applied a standard scaler to the predictors and exported the X_train, X_test, y_train, & y_test sets out to csv files.
#
# I performed PCA on the data set, but because I have reduced the features so much much with the previously mentioned steps, there is not much value in it.  The first two principal components do not seperate out the positive cases from the negative.
#
# Finally I applied a logistic regression to the training data set.  I did not attempt any hyper parameter tuning and the result was pretty good.  I will attempt to improve upon this with more advanced ML techniques in the next notebook.
